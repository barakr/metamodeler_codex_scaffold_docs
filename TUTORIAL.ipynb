# %% [markdown]
# # Tutorial Entry Notebook
#
# Notebook-first tutorial track:
# - Start at `tutorials/Tutorial_0.ipynb`
# - Continue through `tutorials/Tutorial_9.ipynb`

# %%
# %%bash
# cd /Users/barak/Downloads/metamodeler_codex_scaffold_docs
# PYTHONPATH=src python -m metamodeler.cli.main tutorial
